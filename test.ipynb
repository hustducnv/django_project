# %%
from django.utils import timezone

# %%
null
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d910b0287107> in <module>
# ----> 1 null
#
# NameError: name 'null' is not defined

# %%
from
